# %%
# coding=utf-8
from matplotlib import pyplot as plt
import random
import matplotlib


x = range(0,120)
y = [random.randint(20,35) for i in range(120)]

from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']

plt.figure(figsize=(20,8),dpi=80)

plt.plot(x,y)

#调整x轴的刻度
_xtick_labels = ["10:{}".format(i) for i in range(60)]
_xtick_labels += ["11:{}".format(i) for i in range(60)]
#取步长，数字和字符串一一对应，数据的长度一样
plt.xticks(list(x)[::4],_xtick_labels[::4],rotation=30) #rotaion旋转的度数

#添加描述信息
# plt.xlabel("时间")
# plt.ylabel("温度",rotation=90)
plt.title("10点-12点")

plt.show()

# %%
from matplotlib import pyplot as plt

# %%
x = [0,2,3,4]
y = [4,6,-2,3]
plt.scatter(x,y)
plt.show()

# %%
x = 1.34375
y = x**3-x-1
y
# Out:
# 0.082611083984375
